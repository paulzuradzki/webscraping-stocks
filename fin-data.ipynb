# %% [markdown]
# # Web scraping financial market data from Yahoo Finance

# %%
from collections import defaultdict
import bs4
import pandas as pd
import requests

pd.set_option('max_row', 1000)
pd.set_option('max_columns', 1000)

def parse_url_to_df(url, ticker):
    """Shared utility function to convert data from URL to a dataframe.

    Used on Yahoo Finance Key Statistics and Quote pages.
    """
    res = requests.get(url)
    res.raise_for_status()
    soup = bs4.BeautifulSoup(res.text, 'html.parser')
    stats = defaultdict(dict)

    # gather field-value pairs into a `stats` dict
    for x in soup.findAll('tr'):
        stuff = x.findAll('td')
        field, val = stuff[0].text, stuff[1].text
        stats[field] = val
        #for y in x.findAll('td'):
            #print(y.text)

    df = pd.DataFrame.from_dict(stats, orient='index', columns=[ticker])
    return df
    
def get_key_stats(ticker):
    """Returns key statistics for a single stock."""
    url = rf'https://finance.yahoo.com/quote/{ticker}/key-statistics'
    df = parse_url_to_df(url, ticker)    
    return df

def get_quote_stats(ticker):    
    """Returns key statistics for a single stock."""
    url = rf'https://finance.yahoo.com/quote/{ticker}'
    df = parse_url_to_df(url, ticker)
    return df


def get_group(tickers, func, axis=1):
    """Consolidates stats for a list of tickers by dispatching a function that returns a dataframe.
    
    Example
    -------
    >>> stats = get_group(['EVH', 'TSLA', 'UAL', 'DAL', 'AAL', 'BOX', 'DBX'], get_key_stats)
    >>> all_execs = get_group(['EVH', 'TSLA', 'UAL', 'DAL', 'AAL', 'BOX', 'DBX'], get_execs, axis=0)

    ... where get_key_stats and get_execs are functions. 
    """

    data = pd.DataFrame()

    for stock in tickers:
        data = pd.concat([data, func(stock)], axis=axis)
        
    return data.T

def get_execs(ticker):
    """Returns dataframe of exec for single company given ticker.
    
    Example
    -------
    >>> tsla_execs = get_execs('TSLA')
    >>> tsla_execs
    |    | name                    | title                                       | exercised   |   year_born | co   |
    |---:|:------------------------|:--------------------------------------------|:------------|------------:|:-----|
    |  0 | Mr. Elon R. Musk        | Co-Founder, CEO & Director                  | N/A         |        1972 | TSLA |
    |  1 | Mr. Jeffrey B. Straubel | Sr. Advisor                                 | 9.41M       |        1976 | TSLA |
    |  2 | Mr. Jerome  Guillen     | Pres of Automotive Division                 | 1.63M       |        1973 | TSLA |
    |  3 | Mr. Zachary  Kirkhorn   | Chief Financial Officer                     | N/A         |        1985 | TSLA |
    |  4 | Mr. Vaibhav  Taneja     | Corp. Controller & Chief Accounting Officer | N/A         |        1978 | TSLA |

    """
    
    URL = rf'https://finance.yahoo.com/quote/{ticker}/profile'
    res = requests.get(URL)
    res.raise_for_status()
    soup = bs4.BeautifulSoup(res.text, 'html.parser')
    stats = defaultdict(dict)
    
    for x in soup.findAll('tr')[1:]:
        stuff = x.findAll('td')
        name, title, pay, exercised, year_born = stuff[0].text, stuff[1].text, stuff[2].text, stuff[3].text, stuff[4].text
        stats[name] = {'name': name, 'title': title, 'exercised': exercised, 'year_born': year_born}

    df = pd.DataFrame.from_dict(stats, orient='index').reset_index(drop=True)
    df['co'] = ticker
    return df

def get_historical_quotes(ticker):
    url = rf'https://finance.yahoo.com/quote/{ticker}/history'
    res = requests.get(url)
    res.raise_for_status()
    soup = bs4.BeautifulSoup(res.text, 'html.parser')
    stats = defaultdict(dict)

    # gather field-value pairs into a `stats` dict
    for x in soup.findAll('tr')[1:-1]:
        stuff = x.findAll('td')
        date, x_open, hi, lo = stuff[0].text, stuff[1].text, stuff[2].text, stuff[3].text
        close, adj_close, volume = stuff[4].text, stuff[5].text, stuff[6].text
        stats[date] = {'open': x_open, 'high': hi, 'low': lo, 'close': close, 'adj_close': adj_close, 'volume': volume}
    #     for y in x.findAll('td'):
    #         print(y.text)

    df = pd.DataFrame.from_dict(stats, orient='index')
    df.index.name = 'date'
    df['co'] = ticker
    return df

# %%
stocks = ['EVH', 'TSLA', 'UAL', 'DAL', 'AAL', 'BOX', 'DBX']

key_stats = get_group(stocks, get_key_stats)
quote_stats = get_group(stocks, get_quote_stats)
all_execs = get_group(stocks, get_execs, axis=0).T
hist = get_historical_quotes('TSLA')

# %%
# key_stats
# quote_stats
# all_execs

# %%
key_stats
# Out:
#      Market Cap (intraday) 5 Enterprise Value 3 Trailing P/E  Forward P/E 1  \
# EVH                  591.59M            945.36M           N/A       -744.00
# TSLA                 108.85B            137.49B           N/A         43.74
# UAL                    11.6B             28.42B          4.04          3.33
# DAL                    28.4B             44.36B          5.96          5.52
# AAL                    6.28B             36.42B          3.89          2.69
# BOX                    1.96B              2.44B           N/A         20.70
# DBX                     7.4B              7.98B           N/A         19.63
#
#      PEG Ratio (5 yr expected) 1 Price/Sales (ttm) Price/Book (mrq)  \
# EVH                        -0.80              0.70             0.68
# TSLA                        2.40              4.43            16.63
# UAL                         0.35              0.27             1.02
# DAL                         0.73              0.60             1.81
# AAL                         0.28              0.14              N/A
# BOX                         4.69              2.82            88.11
# DBX                         0.78              4.46             9.11
#
#      Enterprise Value/Revenue 3 Enterprise Value/EBITDA 6 Beta (5Y Monthly)   \
# EVH                        1.12                    -15.55               1.07
# TSLA                       5.59                     62.87               0.48
# UAL                        0.66                      4.23               1.37
# DAL                        0.94                      4.98               1.29
# AAL                        0.80                      5.87               1.90
# BOX                        3.50                    -30.48               1.41
# DBX                        4.80                     84.87                N/A
#
#      52-Week Change 3 S&P500 52-Week Change 3 52 Week High 3 52 Week Low 3  \
# EVH           -36.48%                   6.79%          14.79          5.50
# TSLA          141.81%                   6.79%         968.99        176.99
# UAL           -36.76%                   6.79%          96.03         45.92
# DAL           -10.23%                   6.79%          63.44         42.42
# AAL           -50.17%                   6.79%          35.24         14.46
# BOX           -25.90%                   6.79%          21.19         12.46
# DBX           -14.27%                   6.79%          26.20         16.08
#
#      50-Day Moving Average 3 200-Day Moving Average 3 Avg Vol (3 month) 3  \
# EVH                    10.33                     8.69               1.42M
# TSLA                  725.80                   422.06              18.86M
# UAL                    73.61                    85.04               4.98M
# DAL                    54.84                    56.48               9.02M
# AAL                    25.32                    27.45              13.91M
# BOX                    15.61                    16.41               1.72M
# DBX                    18.53                    18.81               5.53M
#
#      Avg Vol (10 day) 3 Shares Outstanding 5   Float  % Held by Insiders 1  \
# EVH               1.07M               84.72M   77.23M                1.20%
# TSLA              16.9M              184.39M  143.77M               20.66%
# UAL              12.61M              247.95M  232.74M                0.42%
# DAL              23.55M              646.74M  635.01M               50.04%
# AAL              43.34M               428.2M  419.78M               40.01%
# BOX               2.54M              149.63M  146.18M                3.16%
# DBX                4.9M              253.94M  227.46M                2.67%
#
#      % Held by Institutions 1 Shares Short (Feb 13, 2020) 4  \
# EVH                   103.26%                        14.47M
# TSLA                   54.06%                        18.39M
# UAL                   101.09%                        11.88M
# DAL                     0.00%                        22.51M
# AAL                     5.17%                        31.12M
# BOX                    79.16%                         7.09M
# DBX                    74.80%                           NaN
#
#      Short Ratio (Feb 13, 2020) 4 Short % of Float (Feb 13, 2020) 4  \
# EVH                         13.92                            19.38%
# TSLA                         0.76                               N/A
# UAL                          2.34                             6.31%
# DAL                          3.05                             3.87%
# AAL                          2.83                             8.37%
# BOX                          4.86                             5.00%
# DBX                           NaN                               NaN
#
#      Short % of Shares Outstanding (Feb 13, 2020) 4  \
# EVH                                          17.08%
# TSLA                                         10.14%
# UAL                                           4.73%
# DAL                                           3.52%
# AAL                                           7.30%
# BOX                                           4.71%
# DBX                                             NaN
#
#      Shares Short (prior month Jan 14, 2020) 4 Forward Annual Dividend Rate 4  \
# EVH                                     15.58M                            N/A
# TSLA                                    24.95M                            N/A
# UAL                                     12.04M                            N/A
# DAL                                     20.89M                           1.61
# AAL                                     42.66M                            0.4
# BOX                                      6.33M                            N/A
# DBX                                        NaN                            N/A
#
#      Forward Annual Dividend Yield 4 Trailing Annual Dividend Rate 3  \
# EVH                              N/A                             N/A
# TSLA                             N/A                             N/A
# UAL                              N/A                             N/A
# DAL                            3.58%                            1.50
# AAL                            2.49%                            0.40
# BOX                              N/A                             N/A
# DBX                              N/A                             N/A
#
#      Trailing Annual Dividend Yield 3 5 Year Average Dividend Yield 4  \
# EVH                               N/A                             N/A
# TSLA                              N/A                             N/A
# UAL                               N/A                             N/A
# DAL                             3.28%                            1.80
# AAL                             2.50%                            1.05
# BOX                               N/A                             N/A
# DBX                               N/A                             N/A
#
#      Payout Ratio 4 Dividend Date 3 Ex-Dividend Date 4 Last Split Factor 2  \
# EVH           0.00%             N/A                N/A                 N/A
# TSLA          0.00%             N/A                N/A                 N/A
# UAL           0.00%    Jan 22, 2008       Jan 06, 2008                 4:1
# DAL          20.62%    Mar 11, 2020       Feb 18, 2020                 N/A
# AAL          10.55%    Feb 18, 2020       Feb 03, 2020                 0:1
# BOX           0.00%             N/A                N/A                 N/A
# DBX           0.00%             N/A                N/A                 N/A
#
#      Last Split Date 3 Fiscal Year Ends  Most Recent Quarter (mrq)  \
# EVH                N/A      Dec 30, 2019              Dec 30, 2019
# TSLA               N/A      Dec 30, 2019              Dec 30, 2019
# UAL       May 20, 1996      Dec 30, 2019              Dec 30, 2019
# DAL                N/A      Dec 30, 2019              Dec 30, 2019
# AAL       Dec 08, 2013      Dec 30, 2019              Dec 30, 2019
# BOX                N/A      Jan 30, 2020              Jan 30, 2020
# DBX                N/A      Dec 30, 2019              Dec 30, 2019
#
#      Profit Margin  Operating Margin (ttm) Return on Assets (ttm)  \
# EVH         -35.68%                -12.17%                 -4.00%
# TSLA         -3.51%                  0.32%                  0.16%
# UAL           6.96%                 10.56%                  5.62%
# DAL          10.14%                 14.15%                  6.66%
# AAL           3.68%                  8.50%                  4.03%
# BOX         -20.73%                -20.03%                -10.86%
# DBX          -3.17%                 -4.78%                 -2.26%
#
#      Return on Equity (ttm) Revenue (ttm) Revenue Per Share (ttm)  \
# EVH                 -28.85%       846.38M                   10.28
# TSLA                -10.75%        24.58B                  138.86
# UAL                  27.90%        43.26B                  167.15
# DAL                  32.83%        47.01B                   72.21
# AAL                     N/A        45.77B                  103.23
# BOX                -536.99%       696.26M                    4.71
# DBX                  -7.10%         1.66B                    4.04
#
#      Quarterly Revenue Growth (yoy) Gross Profit (ttm)  EBITDA   \
# EVH                          22.50%            197.55M   -60.8M
# TSLA                          2.20%              4.07B    2.19B
# UAL                           3.80%             14.78B    6.72B
# DAL                           6.50%             12.92B    8.91B
# AAL                           3.40%             12.56B    6.21B
# BOX                          12.10%            480.69M  -80.05M
# DBX                          18.60%              1.25B      94M
#
#      Net Income Avi to Common (ttm) Diluted EPS (ttm)  \
# EVH                        -301.97M             -3.67
# TSLA                          -862M             -4.92
# UAL                           3.01B             11.58
# DAL                           4.77B              7.30
# AAL                           1.69B              3.79
# BOX                        -144.35M             -0.98
# DBX                          -52.7M             -0.13
#
#      Quarterly Earnings Growth (yoy) Total Cash (mrq)  \
# EVH                              N/A          102.81M
# TSLA                         -25.00%            6.27B
# UAL                           39.00%            4.94B
# DAL                            7.80%            2.89B
# AAL                           27.80%            3.83B
# BOX                              N/A          195.59M
# DBX                              N/A            1.16B
#
#      Total Cash Per Share (mrq) Total Debt (mrq) Total Debt/Equity (mrq)  \
# EVH                        1.21          368.79M                   39.70
# TSLA                      34.56            14.7B                  181.22
# UAL                       19.94           20.45B                  177.35
# DAL                        4.54           17.99B                  117.17
# AAL                        8.98           33.44B                     N/A
# BOX                         1.3          424.54M                1,898.92
# DBX                        2.77            1.01B                  124.53
#
#      Current Ratio (mrq) Book Value Per Share (mrq) Operating Cash Flow (ttm)  \
# EVH                 1.19                      10.90                   -42.65M
# TSLA                1.13                      36.56                      2.4B
# UAL                 0.55                      45.90                     6.91B
# DAL                 0.41                      23.99                     8.42B
# AAL                 0.45                      -0.28                     3.82B
# BOX                 0.79                       0.15                    44.71M
# DBX                 1.23                       1.94                    528.5M
#
#      Levered Free Cash Flow (ttm) Shares Short  4 Short Ratio  4  \
# EVH                        25.45M             NaN            NaN
# TSLA                        1.45B             NaN            NaN
# UAL                         1.24B             NaN            NaN
# DAL                         2.27B             NaN            NaN
# AAL                       -17.75M             NaN            NaN
# BOX                       126.84M             NaN            NaN
# DBX                       389.48M             N/A            N/A
#
#      Short % of Float  4 Short % of Shares Outstanding  4  \
# EVH                  NaN                              NaN
# TSLA                 NaN                              NaN
# UAL                  NaN                              NaN
# DAL                  NaN                              NaN
# AAL                  NaN                              NaN
# BOX                  NaN                              NaN
# DBX                  N/A                              N/A
#
#      Shares Short (prior month ) 4
# EVH                            NaN
# TSLA                           NaN
# UAL                            NaN
# DAL                            NaN
# AAL                            NaN
# BOX                            NaN
# DBX                            N/A

# %%
quote_stats
# Out:
#      Previous Close    Open          Bid          Ask      Day's Range  \
# EVH            7.94    7.63   0.00 x 800   7.46 x 800      7.12 - 7.88
# TSLA         703.48  605.39  0.00 x 3100  0.00 x 1800  605.00 - 663.00
# UAL           52.10   49.58  0.00 x 1200   0.00 x 800    45.92 - 50.99
# DAL           45.89   43.04   0.00 x 900  44.11 x 900    42.42 - 45.01
# AAL           15.97   14.87   0.00 x 900  0.00 x 2200    14.46 - 15.79
# BOX           14.68   13.99   0.00 x 900   0.00 x 900    13.00 - 14.11
# DBX           19.41   18.46  0.00 x 1400  0.00 x 1800    17.63 - 18.46
#
#         52 Week Range      Volume Avg. Volume Market Cap Beta (5Y Monthly)  \
# EVH      5.50 - 14.79     999,394   1,416,349   591.592M              1.07
# TSLA  176.99 - 968.99  17,073,740  18,857,003    108.85B              0.48
# UAL     45.92 - 96.03  12,307,563   4,978,306    11.714B              1.37
# DAL     42.42 - 63.44  25,599,851   9,023,767    28.402B              1.29
# AAL     14.46 - 35.24  42,558,021  13,911,763     6.284B              1.90
# BOX     12.46 - 21.19   3,021,583   1,715,808     1.964B              1.41
# DBX     16.08 - 26.20   5,276,806   5,532,198     7.401B               N/A
#
#      PE Ratio (TTM) EPS (TTM)                Earnings Date  \
# EVH             N/A     -3.67                 Feb 24, 2020
# TSLA            N/A     -4.92  Apr 21, 2020 - Apr 26, 2020
# UAL            4.04     11.58  Apr 13, 2020 - Apr 19, 2020
# DAL            5.96      7.30  Apr 07, 2020 - Apr 12, 2020
# AAL            3.89      3.79  Apr 23, 2020 - Apr 27, 2020
# BOX             N/A     -0.98  May 31, 2020 - Jun 04, 2020
# DBX             N/A     -0.13                 Feb 19, 2020
#
#      Forward Dividend & Yield Ex-Dividend Date 1y Target Est
# EVH                 N/A (N/A)              N/A         15.44
# TSLA                N/A (N/A)              N/A        504.33
# UAL                 N/A (N/A)     Jan 06, 2008         97.13
# DAL              1.61 (3.58%)     Feb 18, 2020         66.63
# AAL              0.40 (2.49%)     Feb 03, 2020         29.93
# BOX                 N/A (N/A)              N/A         18.33
# DBX                 N/A (N/A)              N/A         28.92

# %%
all_execs
# Out:
#                          name                                          title  \
# 0       Mr. Frank J. Williams                     Co-Founder, CEO & Chairman
# 1          Mr. Seth  Blackley                    Co-Founder, Pres & Director
# 2    Mr. Thomas  Peterson III                               Co-Founder & COO
# 3    Mr. Jonathan D. Weinberg       Chief Legal Officer, Gen. Counsel & Sec.
# 4        Dr. Norman C. Payson                                        Advisor
# 0            Mr. Elon R. Musk                     Co-Founder, CEO & Director
# 1     Mr. Jeffrey B. Straubel                                    Sr. Advisor
# Nov 22, 2019  340.16  341.00  330.00  333.04    333.04  16,870,600  TSLA
# Nov 21, 2019  354.51  360.84  354.00  354.83    354.83   6,110,000  TSLA
# Nov 20, 2019  360.00  361.20  349.57  352.22    352.22   6,725,100  TSLA
# Nov 19, 2019  351.75  359.99  347.80  359.52    359.52   7,724,800  TSLA
# Nov 18, 2019  352.92  353.15  346.10  349.99    349.99   4,400,400  TSLA
# Nov 15, 2019  350.64  352.80  348.36  352.17    352.17   4,809,000  TSLA
# Nov 14, 2019  346.11  353.84  342.91  349.35    349.35   6,464,900  TSLA
# Nov 13, 2019  355.00  356.33  345.18  346.11    346.11   8,420,100  TSLA
# Nov 12, 2019  346.90  350.37  344.04  349.93    349.93   7,359,400  TSLA
# Nov 11, 2019  343.95  349.19  342.00  345.09    345.09   9,986,700  TSLA
# Nov 08, 2019  334.50  337.46  332.50  337.14    337.14   6,069,200  TSLA
# Nov 07, 2019  329.14  341.50  328.02  335.54    335.54  14,467,300  TSLA
# Nov 06, 2019  318.00  326.72  314.50  326.58    326.58   7,940,900  TSLA
# Nov 05, 2019  319.62  323.51  316.12  317.22    317.22   6,943,400  TSLA
# Nov 04, 2019  314.80  321.94  309.26  317.47    317.47   8,787,000  TSLA
# Nov 01, 2019  316.32  316.48  309.80  313.31    313.31   6,383,900  TSLA
# Oct 31, 2019  313.10  319.00  313.00  314.92    314.92   5,067,000  TSLA
# Oct 30, 2019  313.00  318.79  309.97  315.01    315.01   9,641,800  TSLA
# Oct 29, 2019  319.99  324.30  314.75  316.22    316.22  12,684,300  TSLA
# Oct 28, 2019  327.54  340.84  322.60  327.71    327.71  18,870,300  TSLA
# Oct 25, 2019  297.72  330.00  296.11  328.13    328.13  30,006,100  TSLA
# Oct 24, 2019  298.37  304.93  289.20  299.68    299.68  29,720,900  TSLA
# Oct 23, 2019  254.50  256.14  251.35  254.68    254.68   5,261,100  TSLA
# Oct 22, 2019  254.32  258.33  250.85  255.58    255.58   4,600,800  TSLA
# Oct 21, 2019  258.33  259.50  250.18  253.50    253.50   5,020,300  TSLA
# Oct 18, 2019  260.70  262.80  255.10  256.95    256.95   5,749,800  TSLA

# %% [markdown]
# # Scratch

# %%
from datetime import datetime

def from_e_to_dt(epoch):
    """Convert from epoch time to datetime."""
    dt = datetime.fromtimestamp(epoch)
    return dt

def from_dt_to_e(dt):
    """Convert from datetime to seconds since epoch.
    >>> from_e_to_dt(1583798400)
    >>> from_dt_to_e(from_e_to_dt(1583798400))
    """
    epoch = int(dt.timestamp())
    return epoch

# %%
# download doesn't work
# Yahoo Finance blocks requests that aren't coming from authorized browser

import wget

ticker = 'TSLA'
period1 = 1583366400
period2 = 1583798400
url_template = rf'https://query1.finance.yahoo.com/v7/finance/download/{ticker}?period1={period1}&period2={period2}&interval=1d&events=history&crumb=WHQcTw1fgKa'
print(url_template)
# filename = wget.download(url_template)
# Out:
# https://query1.finance.yahoo.com/v7/finance/download/TSLA?period1=1583366400&period2=1583798400&interval=1d&events=history&crumb=WHQcTw1fgKa
